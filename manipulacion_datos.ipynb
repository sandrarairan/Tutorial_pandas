# %%
# Importamos las librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# Esta linea permite que los graficos sean renderizados directamente en nuestro Notebook
## Carguemos en un pandas dataframe nuestra base de datos
# %matplotlib inline

# %% [markdown]
# Fuente: Portal de Datos Abiertos www.datos.gov.co”, y mencionar la fecha de la última actualización 27 de junio de 2020

# %%
## Leer un Csv
#pd.read_csv es el metodo que nos permite importar los datos desde un CSV y cargarlo en un **DataFrame**, que es la estructura de base de Pandas

# %%
DF_COVID = pd.read_csv('./Casos_positivos_de_COVID-19_en_Colombia.csv',encoding='utf-8')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10,14,16,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Tipo de dato

# %%
type(DF_COVID)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Cuantas filas y columnas tiene nuestro dataframe

# %%
DF_COVID.shape
# Out:
# (73572, 21)

# %% [markdown]
# Visualizemos las columnas

# %%
DF_COVID.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico'],
#       dtype='object')

# %% [markdown]
# Visualiza las primeas cinco filas del DF

# %%
DF_COVID.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve  ...
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve  ...
# 2                Antioquia  Recuperado    50    F    Importado   Leve  ...
# 3                Antioquia  Recuperado    55    M  Relacionado   Leve  ...
# 4                Antioquia  Recuperado    25    M  Relacionado   Leve  ...
#
# ...

# %% [markdown]
# Convertir a Minúsculas

# %%
DF_COVID['Ciudad de ubicación'].str.lower()
# Out:
# 0                bogotá d.c.
# 1        guadalajara de buga
# 2                   medellín
# 3                   medellín
# 4                   medellín
#                 ...
# 73567                soledad
# 73568                soledad
# 73569                soledad
# 73570           barranquilla
# 73571           barranquilla
# Name: Ciudad de ubicación, Length: 73572, dtype: object

# %% [markdown]
# Reemplazar un cadena por otra

# %%
DF_COVID['fecha reporte web'] = DF_COVID['fecha reporte web'].replace("T00:00:00.000", "", regex=True)

# %%
print (DF_COVID.dtypes)
# Out:
# ID de caso                    int64
# Fecha de notificación        object
# Código DIVIPOLA               int64
# Ciudad de ubicación          object
# Departamento o Distrito      object
# atención                     object
# Edad                          int64
# Sexo                         object
# Tipo                         object
# Estado                       object
# País de procedencia          object
# FIS                          object
# Fecha de muerte              object
# Fecha diagnostico            object
# Fecha recuperado             object
# fecha reporte web            object
# Tipo recuperación            object
# Codigo departamento           int64
# Codigo pais                 float64
# Pertenencia etnica           object
# Nombre grupo etnico          object
# dtype: object

# %% [markdown]
# Convertir Date

# %%
from datetime import date

# %%
DF_COVID['fecha reporte web'] = pd.to_datetime(DF_COVID['fecha reporte web'])

# %%
DF_COVID.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA  Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001          Bogotá D.C.
# 1           2  2020-03-06T00:00:00.000            76111  Guadalajara de Buga
# 2           3  2020-03-07T00:00:00.000             5001             Medellín
# 3           4  2020-03-09T00:00:00.000             5001             Medellín
# 4           5  2020-03-09T00:00:00.000             5001             Medellín
#
#   Departamento o Distrito     atención  Edad Sexo         Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F    Importado   Leve  ...
# 1          Valle del Cauca  Recuperado    34    M    Importado   Leve  ...
# 2                Antioquia  Recuperado    50    F    Importado   Leve  ...
# 3                Antioquia  Recuperado    55    M  Relacionado   Leve  ...
# 4                Antioquia  Recuperado    25    M  Relacionado   Leve  ...
#
# ...

# %% [markdown]
# Tamaño del DF

# %%
DF_COVID.shape
# Out:
# (73572, 21)

# %%
Leer un archivo csv

# %%
municipioscolombia = pd.read_csv('./municipioscolombia.csv',encoding='utf-8')

# %%
municipioscolombia.head()
# Out:
#    05002 Abejorral  05  Antioquia       5.75  -75.4166667
# 0   5004  Abriaquí   5  Antioquia  6.6666667   -76.083333
# 1  50006   Acacías  50       Meta  3.9166667   -73.833333
# 2  27006    Acandí  27      Chocó  8.3333333   -77.166667
# 3  41006   Acevedo  41      Huila       1.75   -75.916667
# 4  13006      Achí  13    Bolívar       8.25   -74.500000

# %% [markdown]
# Para cambiar los nombres de las variables del DF , hacemos lo siguiente.

# %%
municipioscolombia.columns
# Out:
# Index(['05002', 'Abejorral', '05', 'Antioquia', '5.75', '-75.4166667'], dtype='object')

# %%
municipioscolombia.columns = ['Codigo', 'Nombre', 'Codigo_departamento', 'Nombre_departamento', 'Latitud', 'Longitud']

# %%
municipioscolombia.head()
# Out:
#    Codigo    Nombre  Codigo_departamento Nombre_departamento    Latitud  \
# 0    5004  Abriaquí                    5           Antioquia  6.6666667
# 1   50006   Acacías                   50                Meta  3.9166667
# 2   27006    Acandí                   27               Chocó  8.3333333
# 3   41006   Acevedo                   41               Huila       1.75
# 4   13006      Achí                   13             Bolívar       8.25
#
#     Longitud
# 0 -76.083333
# 1 -73.833333
# 2 -77.166667
# 3 -75.916667
# 4 -74.500000

# %%
municipioscolombia.shape
# Out:
# (1101, 6)

# %% [markdown]
# Creando una nueva  fila den DF

# %%
municipioscolombia.loc["1102"] = [47980,"Zona Bananera",47,"Magdalena","10.849993",-74.060849 ]

# %%
pd.concat([DF_COVID,municipioscolombia], axis=1)
# Out:
#        ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0             1.0  2020-03-02T00:00:00.000          11001.0
# 1             2.0  2020-03-06T00:00:00.000          76111.0
# 2             3.0  2020-03-07T00:00:00.000           5001.0
# 3             4.0  2020-03-09T00:00:00.000           5001.0
# 4             5.0  2020-03-09T00:00:00.000           5001.0
# ...           ...                      ...              ...
# 73568     73609.0  2020-06-20T00:00:00.000           8758.0
# 73569     73610.0  2020-06-20T00:00:00.000           8758.0
# 73570     73611.0  2020-06-20T00:00:00.000           8001.0
# 73571     73612.0  2020-06-20T00:00:00.000           8001.0
# 1102          NaN                      NaN              NaN
#
#        Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0              Bogotá D.C.              Bogotá D.C.  Recuperado  19.0    F
# 1      Guadalajara de Buga          Valle del Cauca  Recuperado  34.0    M
# ...

# %% [markdown]
# Unir dos DdataFrames

# %%
COVID19 = pd.merge(DF_COVID,municipioscolombia, left_on="Código DIVIPOLA", right_on="Codigo")

# %%
COVID19.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001         Bogotá D.C.
# 1           8  2020-03-09T00:00:00.000            11001         Bogotá D.C.
# 2           9  2020-03-08T00:00:00.000            11001         Bogotá D.C.
# 3          10  2020-03-12T00:00:00.000            11001         Bogotá D.C.
# 4          11  2020-03-11T00:00:00.000            11001         Bogotá D.C.
#
#   Departamento o Distrito     atención  Edad Sexo       Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F  Importado   Leve  ...
# 1              Bogotá D.C.  Recuperado    22    F  Importado   Leve  ...
# 2              Bogotá D.C.  Recuperado    28    F  Importado   Leve  ...
# 3              Bogotá D.C.  Recuperado    36    F  Importado   Leve  ...
# 4              Bogotá D.C.  Recuperado    42    F  Importado   Leve  ...
#
# ...

# %%
COVID19.shape
# Out:
# (73433, 27)

# %% [markdown]
# Eliminar columnas

# %%
COVID19 = COVID19.drop(['Codigo', 'Nombre','Codigo_departamento','Nombre_departamento'], axis=1)

# %% [markdown]
# mostrar las columnas del DF

# %%
COVID19.columns
# Out:
# Index(['ID de caso', 'Fecha de notificación', 'Código DIVIPOLA',
#        'Ciudad de ubicación', 'Departamento o Distrito ', 'atención', 'Edad',
#        'Sexo', 'Tipo', 'Estado', 'País de procedencia', 'FIS',
#        'Fecha de muerte', 'Fecha diagnostico', 'Fecha recuperado',
#        'fecha reporte web', 'Tipo recuperación', 'Codigo departamento',
#        'Codigo pais', 'Pertenencia etnica', 'Nombre grupo etnico', 'Latitud',
#        'Longitud'],
#       dtype='object')

# %%
agrupar y summarise

# %%
COVID19['COUNTER'] =1       #initially, set that counter to 1.
by_ubic_aten = COVID19.groupby(['Ciudad de ubicación','atención'])['COUNTER'].sum() #sum function
print(by_ubic_aten)
# Out:
# Ciudad de ubicación  atención
# Acacías              Casa           9
#                      Recuperado    14
# Acevedo              Recuperado     2
# Agrado               Recuperado     2
# Agua de Dios         Casa           1
#                                    ..
# Zona Bananera        Casa           6
#                      Fallecido      8
#                      Hospital       6
#                      Recuperado    16
# Ábrego               Fallecido      1
# Name: COUNTER, Length: 1338, dtype: int64

# %%
by_ubic_aten.head()
# Out:
# Ciudad de ubicación  atención
# Acacías              Casa           9
#                      Recuperado    14
# Acevedo              Recuperado     2
# Agrado               Recuperado     2
# Agua de Dios         Casa           1
# Name: COUNTER, dtype: int64

# %%
COVID19.groupby('Ciudad de ubicación')[['atención']].count()
# Out:
#                      atención
# Ciudad de ubicación
# Acacías                    23
# Acevedo                     2
# Agrado                      2
# Agua de Dios                4
# Aguachica                  20
# ...                       ...
# Zambrano                    1
# Zarzal                      2
# Zipaquirá                  97
# Zona Bananera              36
# Ábrego                      1
#
# [576 rows x 1 columns]

# %%
Atencion = (COVID19.groupby(['Ciudad de ubicación', 'atención']).size() 
   .sort_values(ascending=False) 
   .reset_index(name='count') 
   .drop_duplicates(subset='atención'))
print(Atencion)
# Out:
#     Ciudad de ubicación      atención  count
# 0           Bogotá D.C.          Casa  10287
# 1           Bogotá D.C.    Recuperado  10044
# 11          Bogotá D.C.      Hospital   1394
# 19          Bogotá D.C.     Fallecido    512
# 53          Bogotá D.C.  Hospital UCI    144
# 718       Roberto Payán          CASA      2

# %%
Filtrar

# %%
COVID19.query('COUNTER == 1 & atención =="Casa"')
# Out:
#        ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 5078        14762  2020-05-12T00:00:00.000            11001
# 5080        14764  2020-05-13T00:00:00.000            11001
# 5238        14922  2020-05-12T00:00:00.000            11001
# 5240        14924  2020-05-12T00:00:00.000            11001
# 5266        14950  2020-05-13T00:00:00.000            11001
# ...           ...                      ...              ...
# 73426       72184  2020-06-20T00:00:00.000             5044
# 73427       72492  2020-06-20T00:00:00.000             5044
# 73428       72495  2020-06-20T00:00:00.000             5044
# 73429       72587  2020-06-20T00:00:00.000             5044
# 73432       72487  2020-06-19T00:00:00.000            73408
#
#       Ciudad de ubicación Departamento o Distrito  atención  Edad Sexo  \
# 5078          Bogotá D.C.              Bogotá D.C.     Casa    11    F
# 5080          Bogotá D.C.              Bogotá D.C.     Casa    30    M
# ...

# %%
Pivot

# %%
Atencion.pivot(index='Ciudad de ubicación', columns='atención', values='count')
# Out:
# atención             CASA     Casa  Fallecido  Hospital  Hospital UCI  \
# Ciudad de ubicación
# Bogotá D.C.           NaN  10287.0      512.0    1394.0         144.0
# Roberto Payán         2.0      NaN        NaN       NaN           NaN
#
# atención             Recuperado
# Ciudad de ubicación
# Bogotá D.C.             10044.0
# Roberto Payán               NaN

# %%
Atencion.head()
# Out:
#    Ciudad de ubicación      atención  count
# 0          Bogotá D.C.          Casa  10287
# 1          Bogotá D.C.    Recuperado  10044
# 11         Bogotá D.C.      Hospital   1394
# 19         Bogotá D.C.     Fallecido    512
# 53         Bogotá D.C.  Hospital UCI    144

# %%
print(Atencion)
# Out:
#     Ciudad de ubicación      atención  count
# 0           Bogotá D.C.          Casa  10287
# 1           Bogotá D.C.    Recuperado  10044
# 11          Bogotá D.C.      Hospital   1394
# 19          Bogotá D.C.     Fallecido    512
# 53          Bogotá D.C.  Hospital UCI    144
# 718       Roberto Payán          CASA      2

# %%
Atencion.shape
# Out:
# (6, 3)

# %%
pivot_Atencion = COVID19.groupby(['Ciudad de ubicación','atención'])['COUNTER'].sum() #sum function

# %%
pivot_Atencion.shape
# Out:
# (1338,)

# %%
pivot_Atencion.head()
# Out:
# Ciudad de ubicación  atención
# Acacías              Casa           9
#                      Recuperado    14
# Acevedo              Recuperado     2
# Agrado               Recuperado     2
# Agua de Dios         Casa           1
# Name: COUNTER, dtype: int64

# %%
Aten = (COVID19.groupby(['Ciudad de ubicación', 'atención']).size() 
   .sort_values(ascending=False) 
   .reset_index(name='count'))
print(Aten)
# Out:
#       Ciudad de ubicación      atención  count
# 0             Bogotá D.C.          Casa  10287
# 1             Bogotá D.C.    Recuperado  10044
# 2            Barranquilla          Casa   5629
# 3     Cartagena de Indias          Casa   2969
# 4     Cartagena de Indias    Recuperado   2954
# ...                   ...           ...    ...
# 1333               Salgar      Hospital      1
# 1334               Galapa  Hospital UCI      1
# 1335               Salgar    Recuperado      1
# 1336               Samacá     Fallecido      1
# 1337               Ábrego     Fallecido      1
#
# [1338 rows x 3 columns]

# %%
Aten.pivot_table(index='Ciudad de ubicación', columns='atención', values='count', fill_value=0)
# Out:
# atención             CASA  Casa  Fallecido  Hospital  Hospital UCI  Recuperado
# Ciudad de ubicación
# Acacías                 0     9          0         0             0          14
# Acevedo                 0     0          0         0             0           2
# Agrado                  0     0          0         0             0           2
# Agua de Dios            0     1          0         0             0           3
# Aguachica               0    17          1         1             0           1
# ...                   ...   ...        ...       ...           ...         ...
# Zambrano                0     1          0         0             0           0
# Zarzal                  0     1          0         1             0           0
# Zipaquirá               0    46          4        10             0          37
# Zona Bananera           0     6          8         6             0          16
# Ábrego                  0     0          1         0             0           0
#
# ...

# %% [markdown]
# “@” sign.

# %%
COVID19.head()
# Out:
#    ID de caso    Fecha de notificación  Código DIVIPOLA Ciudad de ubicación  \
# 0           1  2020-03-02T00:00:00.000            11001         Bogotá D.C.
# 1           8  2020-03-09T00:00:00.000            11001         Bogotá D.C.
# 2           9  2020-03-08T00:00:00.000            11001         Bogotá D.C.
# 3          10  2020-03-12T00:00:00.000            11001         Bogotá D.C.
# 4          11  2020-03-11T00:00:00.000            11001         Bogotá D.C.
#
#   Departamento o Distrito     atención  Edad Sexo       Tipo Estado  ...  \
# 0              Bogotá D.C.  Recuperado    19    F  Importado   Leve  ...
# 1              Bogotá D.C.  Recuperado    22    F  Importado   Leve  ...
# 2              Bogotá D.C.  Recuperado    28    F  Importado   Leve  ...
# 3              Bogotá D.C.  Recuperado    36    F  Importado   Leve  ...
# 4              Bogotá D.C.  Recuperado    42    F  Importado   Leve  ...
#
#           Fecha recuperado fecha reporte web Tipo recuperación  \
# ...

# %%
casos = [1]

# %%
casos
# Out:
# [1]

# %%
#incluir el nombre del objeto precedido por un signo "@"
COVID19.query("COUNTER in @casos")
# Out:
#        ID de caso    Fecha de notificación  Código DIVIPOLA  \
# 0               1  2020-03-02T00:00:00.000            11001
# 1               8  2020-03-09T00:00:00.000            11001
# 2               9  2020-03-08T00:00:00.000            11001
# 3              10  2020-03-12T00:00:00.000            11001
# 4              11  2020-03-11T00:00:00.000            11001
# ...           ...                      ...              ...
# 73428       72495  2020-06-20T00:00:00.000             5044
# 73429       72587  2020-06-20T00:00:00.000             5044
# 73430       72340  2020-06-19T00:00:00.000            25486
# 73431       72345  2020-06-20T00:00:00.000            25839
# 73432       72487  2020-06-19T00:00:00.000            73408
#
#       Ciudad de ubicación Departamento o Distrito     atención  Edad Sexo  \
# 0             Bogotá D.C.              Bogotá D.C.  Recuperado    19    F
# 1             Bogotá D.C.              Bogotá D.C.  Recuperado    22    F
# ...

# %% [markdown]
# df.memory_usage
# Bebe estar atento al tamaño de los objetos que está creando en su programa

# %%
Atencion.memory_usage()
# Out:
# Index                  48
# Ciudad de ubicación    48
# atención               48
# count                  48
# dtype: int64

# %%
COVID19.memory_usage()
# Out:
# Index                       587464
# ID de caso                  587464
# Fecha de notificación       587464
# Código DIVIPOLA             587464
# Ciudad de ubicación         587464
# Departamento o Distrito     587464
# atención                    587464
# Edad                        587464
# Sexo                        587464
# Tipo                        587464
# Estado                      587464
# País de procedencia         587464
# FIS                         587464
# Fecha de muerte             587464
# Fecha diagnostico           587464
# Fecha recuperado            587464
# fecha reporte web           587464
# Tipo recuperación           587464
# Codigo departamento         587464
# Codigo pais                 587464
# Pertenencia etnica          587464
# Nombre grupo etnico         587464
# Latitud                     587464
# Longitud                    587464
# COUNTER                     587464
# dtype: int64

# %% [markdown]
# pd.read_sql / df.to_sql
# La función "read_sql" devuelve un objeto DataFrame
#
# Es un paquete integral que permite una fácil conexión a la mayoría de las bases de datos SQL
# https://www.sqlalchemy.org/
#
# https://docs.sqlalchemy.org/en/13/core/engines.html

# %%
#dialect+driver://username:password@host:port/database
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://username:password@localhost:5432/database')

# %%
connection = engine.connect()

# %%
pd.read_sql(''' SELECT * FROM tabla ''', connection    )
